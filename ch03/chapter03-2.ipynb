# %%
from google.colab import drive

drive.mount('/content/gdrive')

import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img2 = cv2.imread('/content/gdrive/My Drive/디지털 영상처리 강의 관련/Images/test2.png')
cv2_imshow(img2)
RGB_img = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-e0c803ad29b6> in <cell line: 2>()
#       1 img2 = cv2.imread('/content/gdrive/My Drive/디지털 영상처리 강의 관련/Images/test2.png')
# ----> 2 cv2_imshow(img2)
#       3 RGB_img = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
#       4 plt.imshow(RGB_img)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
img=cv2.imread('/content/gdrive/My Drive/디지털 영상처리 강의 관련/chapter01/test1.jfif')
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-d595e3f77246> in <cell line: 2>()
#       1 img=cv2.imread('/content/gdrive/My Drive/디지털 영상처리 강의 관련/chapter01/test1.jfif')
# ----> 2 cv2_imshow(img)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
img=cv2.imread('/content/gdrive/My Drive/디지털 영상처리 강의 관련/chapter01/test1.jfif')
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-d595e3f77246> in <cell line: 2>()
#       1 img=cv2.imread('/content/gdrive/My Drive/디지털 영상처리 강의 관련/chapter01/test1.jfif')
# ----> 2 cv2_imshow(img)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
img2 = cv2.imread('/content/gdrive/My Drive/디지털 영상처리 강의 관련/Images/lena2.jpg')
cv2_imshow(img2)
RGB_img = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-9975a7f5e4a6> in <cell line: 2>()
#       1 img2 = cv2.imread('/content/gdrive/My Drive/디지털 영상처리 강의 관련/Images/lena2.jpg')
# ----> 2 cv2_imshow(img2)
#       3 RGB_img = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
#       4 plt.imshow(RGB_img)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'
